# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Motion correction

# %%
from __future__ import print_function, division
import numpy as np
import matplotlib.pyplot as plt

# %%
img = nib.load('Pitt_0050003_func_minimal.nii')
data = img.get_fdata()

# %%
data.shape #DATA has 61 slices and 196 volumes
# Out:
# (61, 73, 61, 196)

# %%
vol0 = data[..., 0]

# %%
>>> plt.rcParams['image.cmap'] = 'gray'  # default gray colormap
>>> plt.rcParams['image.interpolation'] = 'nearest'

# %%
>>> plt.imshow(vol0[31, :, :].T, origin='lower')  # doctest: +SKIP

>>> plt.title('Sagittal section through first volume') # doctest: +SKIP

>>> plt.xlabel('x axis')  # doctest: +SKIP

>>> plt.ylabel('z axis')  # doctest: +SKIP
# Out:
# Text(0, 0.5, 'z axis')

# %%
>>> TR = 2.0
>>> n_z_slices = 61
>>> time_for_single_slice = TR / n_z_slices
>>> time_for_single_slice
# Out:
# 0.03278688524590164

# %%
>>> time_for_slice_0 = 0
>>> time_for_slice_1 = time_for_single_slice * 8
>>> time_for_slice_1
# Out:
# 0.26229508196721313

# %%
>>> plt.imshow(vol0[:, :, 0])  # doctest: +SKIP
>>> plt.title('Vol 0, z slice 0')  # doctest: +SKIP
#Here’s what the bottom slice looks like, for the first volume:
# Out:
# Text(0.5, 1.0, 'Vol 0, z slice 0')

# %%
#We are going to collect a time series from a sample voxel from this slice, and the slice above it (slice 1):

#Our sample voxel coordinates
vox_x = 14  # voxel coordinate in first dimension
vox_y = 22  # voxel coordinate in second dimension

# %%
#We get the time courses from slice 0 and slice 1:
time_course_slice_0 = data[vox_x, vox_y, 0, :]
time_course_slice_1 = data[vox_x, vox_y, 1, :]
#The times of acquisition of the voxels for slice 0 are at the beginning of each TR:

vol_nos = np.arange(data.shape[-1])
vol_onset_times = vol_nos * TR
times_slice_0 = vol_onset_times

times_slice_1 = vol_onset_times + TR / 2

# %%
from nipype.interfaces import spm
import os

# Define the input file path
input_file = "Pitt_0050003_func_minimal.nii"

# %%
# Create a SliceTiming interface object
slice_timing = spm.SliceTiming()

# Set the input files as a list
slice_timing.inputs.in_files = [os.path.abspath(input_file)]

# %%
# Set the TR (repetition time) value
slice_timing.inputs.time_repetition = 2.0  # Replace with the actual TR value of your data

# %%
# Set the slice timing parameters
slice_timing.inputs.num_slices = 30  # Replace with the actual number of slices in your data
slice_timing.inputs.slice_order = list(range(1, 31))  # Replace with the actual slice order of your data
slice_timing.inputs.time_acquisition = 2.0  # Replace with the actual time acquisition value of your data

# %%
slice_timing.inputs.ref_slice = 1

# %% [markdown]
# ## Slice Timing correction

# %%
import numpy as np
from scipy.interpolate import interp1d

def slice_timing_correction(data, slice_order, TR, TA):
    num_slices, num_rows, num_cols, num_timepoints = data.shape
    corrected_data = np.zeros_like(data)

    # Calculate the slice timing indices
    slice_timings = np.arange(num_slices) * TR / num_slices

    for t in range(num_timepoints):
        for s in range(num_slices):
            # Calculate the slice timing difference for each slice
            timing_difference = slice_timings[s] - slice_order[s] * TA

            # Interpolate the data for each slice using timing difference
            interpolated_data = interpolate_slice(data[:, :, :, t], timing_difference)
            corrected_data[:, :, s, t] = interpolated_data

    return corrected_data

def interpolate_slice(slice_data, timing_difference):
    # Perform slice timing interpolation using linear interpolation
    interp_func = interp1d(np.arange(slice_data.shape[2]), slice_data, axis=2, kind='linear', fill_value='extrapolate')
    interpolated_data = interp_func(timing_difference)

    return interpolated_data

# Define your input data
data = np.random.rand(61, 73, 61, 196)
slice_order = np.arange(data.shape[2])  # Adjust the slice order to match the number of slices
TR = 2.0
TA = TR / len(slice_order)

# Perform slice timing correction
corrected_data = slice_timing_correction(data, slice_order, TR, TA)

# %%
# Save the corrected data to a new NIfTI file
corrected_img = nib.Nifti1Image(corrected_data, affine=nib.load("Pitt_0050003_func_minimal.nii").affine)
nib.save(corrected_img, "Pitt_0050003_func_minimal_stc.nii")

# %% [markdown]
# ## Motion Correction

# %%
import random

def motion_correction(data):
    num_slices, num_rows, num_cols, num_timepoints = data.shape
    corrected_data = data.copy()

    # Iterate over each timepoint
    for t in range(num_timepoints):
        # Generate random motion parameters (translations in x, y, z directions)
        tx = random.uniform(-1, 1)
        ty = random.uniform(-1, 1)
        tz = random.uniform(-1, 1)

        # Apply motion correction to each slice
        for s in range(num_slices):
            # Calculate the translation indices
            tx_idx = int(round(tx * num_cols))
            ty_idx = int(round(ty * num_rows))
            tz_idx = int(round(tz * num_slices))

            # Perform translation by shifting the slice
            corrected_data[s, :, :, t] = translate_slice(data[s, :, :, t], tx_idx, ty_idx, tz_idx)

    return corrected_data

def translate_slice(slice_data, tx, ty, tz):
    num_rows, num_cols = slice_data.shape
    translated_slice = np.zeros_like(slice_data)

    # Iterate over each pixel in the slice
    for r in range(num_rows):
        for c in range(num_cols):
            # Apply translation to each pixel
            new_r = r + ty
            new_c = c + tx

            # Check if the translated pixel is within the slice boundaries
            if 0 <= new_r < num_rows and 0 <= new_c < num_cols:
                translated_slice[new_r, new_c] = slice_data[r, c]

    return translated_slice

# Define your input data
data = np.random.rand(61, 73, 61, 196)

# Perform motion correction
corrected_data = motion_correction(data)

# %%
# Save the corrected data to a NIfTI file
output_filename = 'corrected_data.nii'
nifti_img = nib.Nifti1Image(corrected_data, affine=np.eye(4))
nib.save(nifti_img, output_filename)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-5f2b65e22199> in <module>
#       1 # Save the corrected data to a new NIfTI file
#       2 corrected_img = nib.Nifti1Image(corrected_data, affine=nib.load("Pitt_0050003_func_minimal.nii").affine)
# ----> 3 nib.save(corrected_img, "Pitt_0050003_func_minimal_motion_correction.nii")
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/loadsave.py in save(img, filename, **kwargs)
#     161     # Save the type as expected
#     162     try:
# --> 163         img.to_filename(filename, **kwargs)
#     164     except ImageFileError:
#     165         pass
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/filebasedimages.py in to_filename(self, filename, **kwargs)
#     305         """
#     306         self.file_map = self.filespec_to_file_map(filename)
# --> 307         self.to_file_map(**kwargs)
#     308
#     309     def to_file_map(self, file_map: FileMap | None = None, **kwargs) -> None:
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/nifti1.py in to_file_map(self, file_map, dtype)
#    2217         self.get_data_dtype(finalize=True)
#    2218         try:
# -> 2219             super().to_file_map(file_map, dtype)
#    2220         finally:
#    2221             self.set_data_dtype(img_dtype)
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/analyze.py in to_file_map(self, file_map, dtype)
#    1049         seek_tell(imgf, hdr.get_data_offset(), write0=True)
#    1050         # Write array data
# -> 1051         arr_writer.to_fileobj(imgf)
#    1052         hdrf.close_if_mine()
#    1053         if not hdr_img_same:
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/arraywriters.py in to_fileobj(self, fileobj, order)
#     532         """
#     533         mn, mx = self._writing_range()
# --> 534         array_to_file(
#     535             self._array,
#     536             fileobj,
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/volumeutils.py in array_to_file(data, fileobj, out_dtype, offset, intercept, divslope, mn, mx, order, nan2zero)
#     603         pre_clips = _dt_min_max(in_dtype, *pre_clips)
#     604     if null_scaling and np.can_cast(in_dtype, out_dtype):
# --> 605         return _write_data(data, fileobj, out_dtype, order, pre_clips=pre_clips)
#     606     # Force upcasting for floats by making atleast_1d.
#     607     slope, inter = (np.atleast_1d(v) for v in (divslope, intercept))
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/volumeutils.py in _write_data(data, fileobj, out_dtype, order, in_cast, pre_clips, inter, slope, post_clips, nan_fill)
#     782         if dslice.dtype != out_dtype:
#     783             dslice = dslice.astype(out_dtype)
# --> 784         fileobj.write(dslice.tobytes())
#     785
#     786
#
# ~/anaconda3/lib/python3.8/site-packages/nibabel/openers.py in write(self, b)
#     230
#     231     def write(self, b: bytes, /) -> int | None:
# --> 232         return self.fobj.write(b)
#     233
#     234     def seek(self, pos: int, whence: int = 0, /) -> int:
#
# OSError: [Errno 28] No space left on device

# %% [markdown]
# ## Smoothing

# %%
# import some functionality
import os.path as op
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# %%
vol = f_img_data[:, :, :, 20] # We'll pick the 21st volume (Python is 0-indexed, remember?)

# %%
fwhm = 10
voxelsize = 6

sigma = fwhm / (np.sqrt(8 * np.log(2)) * voxelsize)
smoothed_vol = gaussian_filter(vol, sigma=sigma)

# %%
# Let's plot both the unsmoothed and smoothed volume
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(vol[:, :, 30], cmap='gray') # And we'll pick the 11th axial slice to visualize
plt.axis('off')
plt.title("Unsmoothed volume\n", fontsize=15)

plt.subplot(1, 2, 2)
plt.imshow(smoothed_vol[:, :, 30], cmap='gray')
plt.axis('off')
plt.title('Smoothed volume\n($\sigma = %.1f; FWHM = %s_{mm}$)' % (sigma, fwhm), fontsize=15)
plt.show()

# %% [markdown]
# # Extracting the time series for each voxel or region of interest

# %% [markdown]
# ## Parcel brain in regions

# %%
import numpy as np
from nilearn.input_data import NiftiMasker

# Load the functional image
func_img = 'Pitt_0050003_func_minimal.nii'

# %%
# Initialize the NiftiMasker object with default parameters
masker = NiftiMasker()

# %%
# Fit the masker to the functional image and extract the time series
time_series = masker.fit_transform(func_img)

# %%
# Print the shape of the time series
print("Shape of time series:", time_series.shape)
# Out:
# Shape of time series: (196, 184460)

# %%
import nilearn
import numpy as np
from nilearn.input_data import NiftiLabelsMasker
from nilearn import datasets
from nilearn.connectome import ConnectivityMeasure

# %%
# Load the functional data
func_img = nilearn.image.load_img('Pitt_0050003_func_minimal.nii')

# Load the Harvard-Oxford atlas
atlas_dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
atlas_filename = atlas_dataset.maps

# %%
# Parcel the brain into regions
masker = NiftiLabelsMasker(labels_img=atlas_filename, standardize=True, detrend=True)

# Extract the time series from the functional data for each parcel
time_series = masker.fit_transform(func_img)

# %%
# Compute the connectivity matrix
correlation_measure = ConnectivityMeasure(kind='partial correlation')
correlation_matrix = correlation_measure.fit_transform([time_series])[0]

# %%
# Plot the connectivity matrix
import matplotlib.pyplot as plt
plt.imshow(correlation_matrix, cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.title('Harvard-Oxford atlas connectivity')
plt.show()

# %%
from nilearn import datasets
from nilearn import image as nimg
from nilearn import plotting as nplot

# %matplotlib inline
# Out:
# /home/bisera13/anaconda3/lib/python3.8/site-packages/nilearn/datasets/__init__.py:86: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
parcel_dir = '../resources/rois/'
atlas_yeo_2011 = datasets.fetch_atlas_yeo_2011(parcel_dir)

# %%
#Define where to slice the image
cut_coords=(8, -4, 9)
#Show a colorbar
colorbar=True
#Color scheme to show when viewing image
cmap='Paired'

#Plot all parcellation schemas referred to by atlas_yeo_2011
nplot.plot_roi(atlas_yeo_2011['thin_7'], cut_coords=cut_coords, colorbar=colorbar, cmap=cmap, title='thin_7')
nplot.plot_roi(atlas_yeo_2011['thin_17'], cut_coords=cut_coords, colorbar=colorbar, cmap=cmap, title='thin_17')
nplot.plot_roi(atlas_yeo_2011['thick_7'], cut_coords=cut_coords, colorbar=colorbar, cmap=cmap, title='thick_7')
nplot.plot_roi(atlas_yeo_2011['thick_17'], cut_coords=cut_coords, colorbar=colorbar, cmap=cmap, title='thick_17')

# %%
atlas_yeo = atlas_yeo_2011['thick_7']

# %% [markdown]
# ## Extracting the time series for each voxel or region of interest (ROI).

# %% [markdown]
# ## Atlas

# %%
import nibabel as nib
import nilearn.input_data as input_data

# %%
# Load the functional image
func_img = nib.load('Pitt_0050003_func_minimal.nii')

# %%
# Load the parcellation atlas image
atlas_img = nib.load('BN_Atlas_246_1mm.nii')

# %%
# Create the masker using the atlas image
masker = input_data.NiftiLabelsMasker(labels_img=atlas_img, standardize=True)

# %%
# Extract the time series for each ROI
time_series = masker.fit_transform(func_img)

# %%
# Print the shape of the time series array
print(time_series.shape)
# Out:
# (196, 246)

# %% [markdown]
# ## K Means Clustering

# %%
import numpy as np
import nibabel as nib
from sklearn.cluster import KMeans

# Load the functional MRI data
file_path = "Pitt_0050003_func_minimal.nii"
img = nib.load(file_path)
data = img.get_fdata()

# Reshape the data to 2D matrix (voxels as rows, time points as columns)
num_voxels = np.prod(data.shape[:-1])
num_timepoints = data.shape[-1]
data_2d = np.reshape(data, (num_voxels, num_timepoints))

# Apply K-means clustering
num_clusters = 10  # Define the desired number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
cluster_labels = kmeans.fit_predict(data_2d)

# Extract time series for each voxel or region of interest
time_series = []
for label in range(num_clusters):
    cluster_voxels = data_2d[cluster_labels == label]
    cluster_time_series = np.mean(cluster_voxels, axis=0)
    time_series.append(cluster_time_series)

# Save the extracted time series to a file
output_file = "time_series.txt"
np.savetxt(output_file, np.array(time_series))

print("Time series extraction completed and saved to", output_file)
# Out:
# /home/bisera13/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f3565732040>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355cf9d160>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355c9f1af0>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f3565732040>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355cf9d160>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355c9f1af0>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f3565732040>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355cf9d160>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f355c9f1af0>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/overrides.py in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 179, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/overrides.py in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 179, in where
# KeyboardInterrupt:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f3565430430>
# Traceback (most recent call last):
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/bisera13/anaconda3/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Time series extraction completed and saved to time_series.txt

# %% [markdown]
# ## Seed based correlation

# %%
import numpy as np
import nibabel as nib

# Load the fMRI data
fmri_data = nib.load('Pitt_0050003_func_minimal.nii').get_fdata()
# Assuming the dimensions of fmri_data are (x, y, z, t)

# Define the coordinates of the seed voxel
seed_x = 30
seed_y = 40
seed_z = 20

# Extract the time series for the seed voxel
seed_time_series = fmri_data[seed_x, seed_y, seed_z, :]

# Calculate the correlation between the seed time series and all other voxels
correlations = np.zeros((fmri_data.shape[0], fmri_data.shape[1], fmri_data.shape[2]))
for x in range(fmri_data.shape[0]):
    for y in range(fmri_data.shape[1]):
        for z in range(fmri_data.shape[2]):
            voxel_time_series = fmri_data[x, y, z, :]
            correlations[x, y, z] = np.corrcoef(seed_time_series, voxel_time_series)[0, 1]

# Save the correlation map as a NIfTI file
correlation_img = nib.Nifti1Image(correlations, affine=nib.load('Pitt_0050003_func_minimal.nii').affine)
nib.save(correlation_img, 'seed_correlation_map.nii')
# Out:
# /home/bisera13/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/bisera13/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-8f955e06c1e0> in <module>
#      20         for z in range(fmri_data.shape[2]):
#      21             voxel_time_series = fmri_data[x, y, z, :]
# ---> 22             correlations[x, y, z] = np.corrcoef(seed_time_series, voxel_time_series)[0, 1]
#      23
#      24 # Save the correlation map as a NIfTI file
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/overrides.py in corrcoef(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2846     c = cov(x, y, rowvar, dtype=dtype)
#    2847     try:
# -> 2848         d = diag(c)
#    2849     except ValueError:
#    2850         # scalar covariance
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/overrides.py in diag(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/twodim_base.py in _diag_dispatcher(v, k)
#     234
#     235
# --> 236 def _diag_dispatcher(v, k=None):
#     237     return (v,)
#     238
#
# KeyboardInterrupt:

# %% [markdown]
# # Calculating the functional connectivity matrix using correlation, partial correlation, or another similarity measure

# %%
import numpy as np
from scipy import stats
import pingouin as pg
import pandas as pd

# %%
# Convert the time series array into a pandas DataFrame
df = pd.DataFrame(time_series)

# Calculate the correlation matrix
corr_matrix = df.corr()

# Calculate the inverse of the correlation matrix
corr_inv = np.linalg.inv(corr_matrix.values)

# %%
# Initialize the partial correlation matrix with NaN values
partial_corr_matrix = np.empty_like(corr_matrix)
partial_corr_matrix[:] = np.nan

# %%
# Calculate the partial correlation for each pair of variables
for i in range(len(corr_matrix)):
    for j in range(len(corr_matrix)):
        if i != j:
            x = corr_matrix.index[i]
            y = corr_matrix.columns[j]
            xy_corr = corr_matrix.loc[x, y]
            partial_corr = -corr_inv[i, j] / np.sqrt(corr_inv[i, i] * corr_inv[j, j])
            partial_corr_matrix[i, j] = partial_corr
# Out:
# <ipython-input-28-346d6d1eeb1a>:8: RuntimeWarning: invalid value encountered in sqrt
#   partial_corr = -corr_inv[i, j] / np.sqrt(corr_inv[i, i] * corr_inv[j, j])

# %%
# Convert the partial correlation matrix into a pandas DataFrame
partial_corr_df = pd.DataFrame(partial_corr_matrix, index=corr_matrix.index, columns=corr_matrix.columns)

# %% [markdown]
# # Threshold

# %%
# Thresholding parameters
threshold_value1 = 5.0 # Set the threshold value as per your requirement
threshold_value2 = 0.3

# %%
# Thresholding the correlation matrix
adjacency_matrix = np.where(np.abs(partial_corr_df) >= threshold_value1, 1, 0)  # Binary adjacency matrix
weighted_adjacency_matrix = np.where(np.abs(partial_corr_df) >= threshold_value1, partial_corr_df, 0)  # Weighted adjacency matrix

# %%
# Thresholding the correlation matrix
adjacency_matrix1 = np.where(np.abs(partial_corr_df) >= threshold_value2, 1, 0)  # Binary adjacency matrix
weighted_adjacency_matrix1 = np.where(np.abs(partial_corr_df) >= threshold_value2, partial_corr_df, 0)  # Weighted adjacency matrix

# %% [markdown]
# # Create the graph

# %%
import networkx as nx

# %%
# Create a graph from the weighted adjacency matrix
graph = nx.from_numpy_array(weighted_adjacency_matrix)

# %%
# Optional: Set the labels of the nodes if available
node_labels = range(weighted_adjacency_matrix.shape[0])  # Assuming each row/column represents a node
labels = {i: label for i, label in enumerate(node_labels)}
nx.set_node_attributes(graph, labels, 'label')

# %%
# Optional: Set the edge weights as attributes
edge_weights = {(u, v): weight for (u, v, weight) in graph.edges(data='weight')}
nx.set_edge_attributes(graph, edge_weights, 'weight')

# %%
# Optional: Visualize the graph
nx.draw(graph, with_labels=True)

# %% [markdown]
# ### Degree distribution

# %%
import matplotlib.pyplot as plt

# %%
degree_distribution = [degree for (_, degree) in graph.degree()]
# Plot the degree distribution
plt.hist(degree_distribution, bins=20)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Degree Distribution')
plt.show()

# %% [markdown]
# ###  Clustering coefficient

# %%
#Average clustering coefficient
average_clustering_coefficient = nx.average_clustering(graph)
print("Average Clustering Coefficient:", average_clustering_coefficient)
# Out:
# Average Clustering Coefficient: 0.791916729213125

# %%
#Histogram or distribution
clustering_coefficients = list(nx.clustering(graph).values())
plt.hist(clustering_coefficients, bins=20)
plt.xlabel("Clustering Coefficient")
plt.ylabel("Frequency")
plt.title("Clustering Coefficient Distribution")
plt.show()

# %%
#Node level distribution 
clustering_coefficients = nx.clustering(graph)
nodes = list(graph.nodes())
coefficients = [clustering_coefficients[node] for node in nodes]
plt.scatter(nodes, coefficients)
plt.xlabel("Node")
plt.ylabel("Clustering Coefficient")
plt.title("Clustering Coefficient per Node")
plt.show()

# %% [markdown]
# ### Shortest path

# %%
#Single shortest path
source = 1  # Source node
target = 10  # Target node
shortest_path = nx.shortest_path(graph, source, target)
print("Shortest Path:", shortest_path)
# Out:
# Shortest Path: [1, 0, 10]

# %%
#All shortest paths 
shortest_paths = dict(nx.shortest_path_length(graph))
print("Shortest Paths:", shortest_paths)
# Out:
# Shortest Paths: {0: {0: 0, 1: 1, 2: 1, 5: 1, 6: 1, 7: 1, 8: 1, 9: 1, 10: 1, 12: 1, 17: 1, 18: 1, 19: 1, 21: 1, 26: 1, 28: 1, 29: 1, 33: 1, 35: 1, 36: 1, 37: 1, 38: 1, 41: 1, 42: 1, 45: 1, 50: 1, 51: 1, 54: 1, 56: 1, 62: 1, 64: 1, 67: 1, 69: 1, 71: 1, 72: 1, 73: 1, 76: 1, 77: 1, 78: 1, 80: 1, 83: 1, 88: 1, 89: 1, 90: 1, 91: 1, 94: 1, 95: 1, 99: 1, 101: 1, 102: 1, 103: 1, 105: 1, 106: 1, 107: 1, 108: 1, 110: 1, 112: 1, 114: 1, 115: 1, 118: 1, 123: 1, 124: 1, 125: 1, 126: 1, 128: 1, 130: 1, 132: 1, 133: 1, 136: 1, 137: 1, 142: 1, 143: 1, 146: 1, 147: 1, 151: 1, 154: 1, 156: 1, 159: 1, 160: 1, 162: 1, 166: 1, 168: 1, 169: 1, 171: 1, 172: 1, 173: 1, 176: 1, 177: 1, 180: 1, 181: 1, 182: 1, 187: 1, 189: 1, 190: 1, 192: 1, 195: 1, 39: 2, 58: 2, 68: 2}, 1: {1: 0, 0: 1, 195: 1, 37: 1, 136: 1, 171: 1, 77: 1, 78: 1, 142: 1, 114: 1, 118: 1, 91: 1, 125: 1, 2: 2, 5: 2, 6: 2, 7: 2, 8: 2, 9: 2, 10: 2, 12: 2, 17: 2, 18: 2, 19: 2, 21: 2, 26: 2, 28: 2, 29: 2, 33: 2, 35: 2, 36: 2, 38: 2, 39: 2, 41: 2, 42: 2, 45: 2, 50: 2, 51: 2, 54: 2, 56: 2, 58: 2, 62: 2, 64: 2, 67: 2, 68: 2, 69: 2, 71: 2, 72: 2, 73: 2, 76: 2, 80: 2, 83: 2, 88: 2, 89: 2, 90: 2, 94: 2, 95: 2, 99: 2, 101: 2, 102: 2, 103: 2, 105: 2, 106: 2, 107: 2, 108: 2, 110: 2, 112: 2, 115: 2, 123: 2, 124: 2, 126: 2, 128: 2, 130: 2, 132: 2, 133: 2, 137: 2, 143: 2, 146: 2, 147: 2, 151: 2, 154: 2, 156: 2, 159: 2, 160: 2, 162: 2, 166: 2, 168: 2, 169: 2, 172: 2, 173: 2, 176: 2, 177: 2, 180: 2, 181: 2, 182: 2, 187: 2, 189: 2, 190: 2, 192: 2}, 2: {2: 0, 0: 1, 171: 1, 78: 1, 114: 1, 118: 1, 91: 1, 1: 2, 5: 2, 6: 2, 7: 2, 8: 2, 9: 2, 10: 2, 12: 2, 17: 2, 18: 2, 19: 2, 21: 2, 26: 2, 28: 2, 29: 2, 33: 2, 35: 2, 36: 2, 37: 2, 38: 2, 39: 2, 41: 2, 42: 2, 45: 2, 50: 2, 51: 2, 54: 2, 56: 2, 58: 2, 62: 2, 64: 2, 67: 2, 68: 2, 69: 2, 71: 2, 72: 2, 73: 2, 76: 2, 77: 2, 80: 2, 83: 2, 88: 2, 89: 2, 90: 2, 94: 2, 95: 2, 99: 2, 101: 2, 102: 2, 103: 2, 105: 2, 106: 2, 107: 2, 108: 2, 110: 2, 112: 2, 115: 2, 123: 2, 124: 2, 125: 2, 126: 2, 128: 2, 130: 2, 132: 2, 133: 2, 136: 2, 137: 2, 142: 2, 143: 2, 146: 2, 147: 2, 151: 2, 154: 2, 156: 2, 159: 2, 160: 2, 162: 2, 166: 2, 168: 2, 169: 2, 172: 2, 173: 2, 176: 2, 177: 2, 180: 2, 181: 2, 182: 2, 187: 2, 189: 2, 190: 2, 192: 2, 195: 2}, 3: {3: 0, 161: 1, 134: 1, 40: 1, 11: 1, 186: 1, 93: 1, 4: 2, 13: 2, 14: 2, 15: 2, 16: 2, 20: 2, 22: 2, 23: 2, 24: 2, 25: 2, 27: 2, 30: 2, 31: 2, 32: 2, 34: 2, 43: 2, 44: 2, 46: 2, 47: 2, 48: 2, 49: 2, 52: 2, 53: 2, 55: 2, 57: 2, 59: 2, 60: 2, 61: 2, 63: 2, 65: 2, 66: 2, 70: 2, 74: 2, 75: 2, 79: 2, 81: 2, 82: 2, 84: 2, 85: 2, 86: 2, 87: 2, 92: 2, 96: 2, 97: 2, 98: 2, 100: 2, 104: 2, 109: 2, 111: 2, 113: 2, 116: 2, 117: 2, 119: 2, 120: 2, 121: 2, 122: 2, 127: 2, 129: 2, 131: 2, 135: 2, 138: 2, 139: 2, 140: 2, 141: 2, 144: 2, 145: 2, 148: 2, 149: 2, 150: 2, 152: 2, 153: 2, 155: 2, 157: 2, 158: 2, 163: 2, 164: 2, 165: 2, 167: 2, 170: 2, 174: 2, 175: 2, 178: 2, 179: 2, 183: 2, 184: 2, 185: 2, 188: 2, 191: 2, 193: 2, 194: 2}, 4: {4: 0, 161: 1, 163: 1, 40: 1, 13: 1, 82: 1, 23: 1, 186: 1, 3: 2, 11: 2, 14: 2, 15: 2, 16: 2, 20: 2, 22: 2, 24: 2, 25: 2, 27: 2, 30: 2, 31: 2, 32: 2, 34: 2, 43: 2, 44: 2, 46: 2, 47: 2, 48: 2, 49: 2, 52: 2, 53: 2, 55: 2, 57: 2, 59: 2, 60: 2, 61: 2, 63: 2, 65: 2, 66: 2, 70: 2, 74: 2, 75: 2, 79: 2, 81: 2, 84: 2, 85: 2, 86: 2, 87: 2, 92: 2, 93: 2, 96: 2, 97: 2, 98: 2, 100: 2, 104: 2, 109: 2, 111: 2, 113: 2, 116: 2, 117: 2, 119: 2, 120: 2, 121: 2, 122: 2, 127: 2, 129: 2, 131: 2, 134: 2, 135: 2, 138: 2, 139: 2, 140: 2, 141: 2, 144: 2, 145: 2, 148: 2, 149: 2, 150: 2, 152: 2, 153: 2, 155: 2, 157: 2, 158: 2, 164: 2, 165: 2, 167: 2, 170: 2, 174: 2, 175: 2, 178: 2, 179: 2, 183: 2, 184: 2, 185: 2, 188: 2, 191: 2, 193: 2, 194: 2}, 5: {5: 0, 0: 1, 37: 1, 171: 1, 78: 1, 17: 1, 118: 1, 91: 1, 125: 1, 1: 2, 2: 2, 6: 2, 7: 2, 8: 2, 9: 2, 10: 2, 12: 2, 18: 2, 19: 2, 21: 2, 26: 2, 28: 2, 29: 2, 33: 2, 35: 2, 36: 2, 38: 2, 39: 2, 41: 2, 42: 2, 45: 2, 50: 2, 51: 2, 54: 2, 56: 2, 58: 2, 62: 2, 64: 2, 67: 2, 68: 2, 69: 2, 71: 2, 72: 2, 73: 2, 76 ...

# %%
#Visualizing shortest path
shortest_path = nx.shortest_path(graph, source, target)
shortest_path_edges = [(shortest_path[i], shortest_path[i+1]) for i in range(len(shortest_path)-1)]

# Visualize the graph with shortest path highlighted
pos = nx.spring_layout(graph)  # Layout for node positions
nx.draw_networkx_nodes(graph, pos)
nx.draw_networkx_edges(graph, pos)
nx.draw_networkx_edges(graph, pos, edgelist=shortest_path_edges, edge_color='r', width=2)
nx.draw_networkx_labels(graph, pos)
plt.show()

# %% [markdown]
# ### Community detection

# %%
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import community

# Perform community detection using the Louvain algorithm
partition = community.greedy_modularity_communities(graph)

# Create a dictionary of nodes and their corresponding community IDs
node_communities = {}
for i, comm in enumerate(partition):
    for node in comm:
        node_communities[node] = i

# Assign unique colors to each community
community_colors = ['red', 'blue', 'green', 'yellow']  # Add more colors as needed

# Visualize the graph with colored nodes representing communities
pos = nx.spring_layout(graph)  # Layout for node positions
for node in graph.nodes():
    community_id = node_communities[node]
    color = community_colors[community_id % len(community_colors)]
    nx.draw_networkx_nodes(graph, pos, nodelist=[node], node_color=color)

nx.draw_networkx_edges(graph, pos)
nx.draw_networkx_labels(graph, pos)
plt.show()

# %%
#Community subgraphs

# %%
# Perform community detection using the Louvain algorithm
communities1 = community.greedy_modularity_communities(graph)
communities = {}
for i, comm in enumerate(communities1):
    for node in comm:
        communities[node] = i


# Create a subgraph for each community
community_subgraphs = []
for community in set(communities.values()):
    nodes_in_community = [node for node, comm in communities.items() if comm == community]
    community_subgraph = graph.subgraph(nodes_in_community)
    community_subgraphs.append(community_subgraph)

# Visualize each community subgraph
for i, subgraph in enumerate(community_subgraphs):
    pos = nx.spring_layout(subgraph)  # Layout for node positions
    nx.draw_networkx(subgraph, pos)
    plt.title(f"Community {i+1}")
    plt.show()

# %%
#Statistics

# %%
# Calculate community statistics
community_sizes = {}
community_avg_degree = {}
for community in set(communities.values()):
    nodes_in_community = [node for node, comm in communities.items() if comm == community]
    community_sizes[community] = len(nodes_in_community)
    community_subgraph = graph.subgraph(nodes_in_community)
    community_avg_degree[community] = nx.average_degree_connectivity(community_subgraph)

# Print community statistics
for community, size in community_sizes.items():
    print(f"Community {community}: Size = {size}, Average Degree = {community_avg_degree[community]}")
# Out:
# Community 0: Size = 1, Average Degree = {0: 0}
# Community 1: Size = 1, Average Degree = {0: 0}
# Community 2: Size = 1, Average Degree = {0: 0}
# Community 3: Size = 1, Average Degree = {0: 0}
# Community 4: Size = 1, Average Degree = {0: 0}
# Community 5: Size = 1, Average Degree = {0: 0}
# Community 6: Size = 1, Average Degree = {0: 0}
# Community 7: Size = 1, Average Degree = {0: 0}
# Community 8: Size = 1, Average Degree = {0: 0}
# Community 9: Size = 1, Average Degree = {0: 0}
# Community 10: Size = 1, Average Degree = {0: 0}
# Community 11: Size = 1, Average Degree = {0: 0}
# Community 12: Size = 1, Average Degree = {0: 0}
# Community 13: Size = 1, Average Degree = {0: 0}
# Community 14: Size = 1, Average Degree = {0: 0}
# Community 15: Size = 1, Average Degree = {0: 0}
# Community 16: Size = 1, Average Degree = {0: 0}
# Community 17: Size = 1, Average Degree = {0: 0}
# Community 18: Size = 1, Average Degree = {0: 0}
# Community 19: Size = 1, Average Degree = {0: 0}
# Community 20: Size = 1, Average Degree = {0: 0}
# Community 21: Size = 1, Average Degree = {0: 0}
# Community 22: Size = 1, Average Degree = {0: 0}
# Community 23: Size = 1, Average Degree = {0: 0}
# Community 24: Size = 1, Average Degree = {0: 0}
# Community 25: Size = 1, Average Degree = {0: 0}
# Community 26: Size = 1, Average Degree = {0: 0}
# Community 27: Size = 1, Average Degree = {0: 0}
# Community 28: Size = 1, Average Degree = {0: 0}
# Community 29: Size = 1, Average Degree = {0: 0}
# Community 30: Size = 1, Average Degree = {0: 0}
# Community 31: Size = 1, Average Degree = {0: 0}
# Community 32: Size = 1, Average Degree = {0: 0}
# Community 33: Size = 1, Average Degree = {0: 0}
# Community 34: Size = 1, Average Degree = {0: 0}
# Community 35: Size = 1, Average Degree = {0: 0}
# Community 36: Size = 1, Average Degree = {0: 0}
# Community 37: Size = 1, Average Degree = {0: 0}
# Community 38: Size = 1, Average Degree = {0: 0}
# Community 39: Size = 1, Average Degree = {0: 0}
# Community 40: Size = 1, Average Degree = {0: 0}
# Community 41: Size = 1, Average Degree = {0: 0}
# Community 42: Size = 1, Average Degree = {0: 0}
# Community 43: Size = 1, Average Degree = {0: 0}
# Community 44: Size = 1, Average Degree = {0: 0}
# Community 45: Size = 1, Average Degree = {0: 0}
# Community 46: Size = 1, Average Degree = {0: 0}
# Community 47: Size = 1, Average Degree = {0: 0}
# Community 48: Size = 1, Average Degree = {0: 0}
# Community 49: Size = 1, Average Degree = {0: 0}
# Community 50: Size = 1, Average Degree = {0: 0}
# Community 51: Size = 1, Average Degree = {0: 0}
# Community 52: Size = 1, Average Degree = {0: 0}
# Community 53: Size = 1, Average Degree = {0: 0}
# Community 54: Size = 1, Average Degree = {0: 0}
# Community 55: Size = 1, Average Degree = {0: 0}
# Community 56: Size = 1, Average Degree = {0: 0}
# Community 57: Size = 1, Average Degree = {0: 0}
# Community 58: Size = 1, Average Degree = {0: 0}
# Community 59: Size = 1, Average Degree = {0: 0}
# Community 60: Size = 1, Average Degree = {0: 0}
# Community 61: Size = 1, Average Degree = {0: 0}
# Community 62: Size = 1, Average Degree = {0: 0}
# Community 63: Size = 1, Average Degree = {0: 0}
# Community 64: Size = 1, Average Degree = {0: 0}
# Community 65: Size = 1, Average Degree = {0: 0}
# Community 66: Size = 1, Average Degree = {0: 0}
# Community 67: Size = 1, Average Degree = {0: 0}
# Community 68: Size = 1, Average Degree = {0: 0}
# Community 69: Size = 1, Average Degree = {0: 0}
# Community 70: Size = 1, Average Degree = {0: 0}
# Community 71: Size = 1, Average Degree = {0: 0}
# Community 72: Size = 1, Average Degree = {0: 0}
# Community 73: Size = 1, Average Degree = {0: 0}
# Community 74: Size = 1, Average Degree = {0: 0}
# Community 75: Size = 1, Average Degree = {0: 0}
# Community 76: Size = 1, Average Degree = {0: 0}
# Community 77: Size = 1, Average Degree = {0: 0}
# Community 78: Size = 1, Average Degree = {0: 0}
# Community 79: Size = 1, Average Degree = {0: 0}
# Community 80: Size = 1, Average Degree = {0: 0}
# Community 81: Size = 1, Average Degree = {0: 0}
# Community 82: Size = 1, Average Degree = {0: 0}
# Community 83: Size = 1, Average Degree = {0: 0}
# Community 84: Size = 1, Average Degree = {0: 0}
# Community 85: Size = 1, Average Degree = {0: 0}
# Community 86: Size = 1, Average Degree = {0: 0}
# Community 87: Size = 1, Average Degree = {0: 0}
# Community 88: Size = 1, Average Degree = {0: 0}
# Community 89: Size = 1, Average Degree = {0: 0}
# Community 90: Size = 1, Average Degree = {0: 0}
# Community 91: Size = 1, Average Degree = {0: 0}
# Community 92: Size = 1, Average Degree = {0: 0}
# Community 93: Size = 1, Average Degree = {0: 0}
# Community 94: Size = 1, Average Degree = {0: 0}
# Community 95: Size = 1, Average Degree = {0: 0}
# Community 96: Size = 1, Average Degree = {0: 0}
# Community 97: Size = 1, Average Degree = {0: 0}
# Community 98: Size = 1, Average Degree = {0: 0}
# Community 99: Size = 1, Average Degree = {0: 0}
# Community 100: Size = 1, Average Degree = {0: 0}
# Community 101: Size = 1, Average Degree = {0: 0}
# Community 102: Size = 1, Average Degree = {0: 0}
# Community 103: Size = 1, Average Degree = {0: 0}
# Community 104: Size = 1, Average Degree = {0: 0}
# Community 105: Size = 1, Average Degree = {0: 0}
# Community 106: Size = 1, Average Degree = {0: 0}
# Community 107: Size = 1, Average Degree = {0: 0}
# Community 108: Size = 1, Average Degree = {0: 0}
# Community 109: Size = 1, Average Degree = {0: 0}
# Community 110: Size = 1, Average Degree = {0: 0}
# Community 111: Size = 1, Average Degree = {0: 0}
# Community 112: Size = 1, Average Degree = {0: 0}
# Community 113: Size = 1, Average Degree = {0: 0}
# Community 114: Size = 1, Average Degree = {0: 0}
# Community 115: Size = 1, Average Degree = {0: 0}
# Community 116: Size = 1, Average Degree = {0: 0}
# Community 117: Size = 1, Average Degree = {0: 0}
# Community 118: Size = 1, Average Degree = {0: 0}
# Community 119: Size = 1, Average Degree = {0: 0}
# Community 120: Size = 1, Average Degree = {0: 0}
# Community 121: Size = 1, Average Degree = {0: 0}
# Community 122: Size = 1, Average Degree = {0: 0}
# Community 123: Size = 1, Average Degree = {0: 0}
# Community 124: Size = 1, Average Degree = {0: 0}
# Community 125: Size = 1, Average Degree = {0: 0}
# Community 126: Size = 1, Average Degree = {0: 0}
# Community 127: Size = 1, Average Degree = {0: 0}
# Community 128: Size = 1, Average Degree = {0: 0}
# Community 129: Size = 1, Average Degree = {0: 0}
# Community 130: Size = 1, Average Degree = {0: 0}
# Community 131: Size = 1, Average Degree = {0: 0}
# Community 132: Size = 1, Average Degree = {0: 0}
# Community 133: Size = 1, Average Degree = {0: 0}
# Community 134: Size = 1, Average Degree = {0: 0}
# Community 135: Size = 1, Average Degree = {0: 0}
# Community 136: Size = 1, Average Degree = {0: 0}
# Community 137: Size = 1, Average Degree = {0: 0}
# Community 138: Size = 1, Average Degree = {0: 0}
# Community 139: Size = 1, Average Degree = {0: 0}
# Community 140: Size = 1, Average Degree = {0: 0}
# Community 141: Size = 1, Average Degree = {0: 0}
# Community 142: Size = 1, Average Degree = {0: 0}
# Community 143: Size = 1, Average Degree = {0: 0}
# Community 144: Size = 1, Average Degree = {0: 0}
# Community 145: Size = 1, Average Degree = {0: 0}
# Community 146: Size = 1, Average Degree = {0: 0}
# Community 147: Size = 1, Average Degree = {0: 0}
# Community 148: Size = 1, Average Degree = {0: 0}
# Community 149: Size = 1, Average Degree = {0: 0}
# Community 150: Size = 1, Average Degree = {0: 0}
# Community 151: Size = 1, Average Degree = {0: 0}
# Community 152: Size = 1, Average Degree = {0: 0}
# Community 153: Size = 1, Average Degree = {0: 0}
# Community 154: Size = 1, Average Degree = {0: 0}
# Community 155: Size = 1, Average Degree = {0: 0}
# Community 156: Size = 1, Average Degree = {0: 0}
# Community 157: Size = 1, Average Degree = {0: 0}
# Community 158: Size = 1, Average Degree = {0: 0}
# Community 159: Size = 1, Average Degree = {0: 0}
# Community 160: Size = 1, Average Degree = {0: 0}
# Community 161: Size = 1, Average Degree = {0: 0}
# Community 162: Size = 1, Average Degree = {0: 0}
# Community 163: Size = 1, Average Degree = {0: 0}
# Community 164: Size = 1, Average Degree = {0: 0}
# Community 165: Size = 1, Average Degree = {0: 0}
# Community 166: Size = 1, Average Degree = {0: 0}
# Community 167: Size = 1, Average Degree = {0: 0}
# Community 168: Size = 1, Average Degree = {0: 0}
# Community 169: Size = 1, Average Degree = {0: 0}
# Community 170: Size = 1, Average Degree = {0: 0}
# Community 171: Size = 1, Average Degree = {0: 0}
# Community 172: Size = 1, Average Degree = {0: 0}
# Community 173: Size = 1, Average Degree = {0: 0}
# Community 174: Size = 1, Average Degree = {0: 0}
# Community 175: Size = 1, Average Degree = {0: 0}
# Community 176: Size = 1, Average Degree = {0: 0}
# Community 177: Size = 1, Average Degree = {0: 0}
# Community 178: Size = 1, Average Degree = {0: 0}
# Community 179: Size = 1, Average Degree = {0: 0}
# Community 180: Size = 1, Average Degree = {0: 0}
# Community 181: Size = 1, Average Degree = {0: 0}
# Community 182: Size = 1, Average Degree = {0: 0}
# Community 183: Size = 1, Average Degree = {0: 0}
# Community 184: Size = 1, Average Degree = {0: 0}
# Community 185: Size = 1, Average Degree = {0: 0}
# Community 186: Size = 1, Average Degree = {0: 0}
# Community 187: Size = 1, Average Degree = {0: 0}
# Community 188: Size = 1, Average Degree = {0: 0}
# Community 189: Size = 1, Average Degree = {0: 0}
# Community 190: Size = 1, Average Degree = {0: 0}
# Community 191: Size = 1, Average Degree = {0: 0}
# Community 192: Size = 1, Average Degree = {0: 0}
# Community 193: Size = 1, Average Degree = {0: 0}
# Community 194: Size = 1, Average Degree = {0: 0}
# Community 195: Size = 1, Average Degree = {0: 0}
